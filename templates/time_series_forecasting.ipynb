# %% [markdown]
# # Problem Statement

# %% [markdown]
# # Data Folder

# %%
# Process File
# !python -m wget https://raw.githubusercontent.com/train-your-model/helper_functions/master/dir_paths.py
# !python -m wget https://raw.githubusercontent.com/train-your-model/helper_functions/master/process_file.py

# %%
import process_file as pf

# %%
data_fold = pf.MoveDatafold(targ_dt="")

# %%
data_fold()

# %% [markdown]
# # Data Imports

# %%
import pandas as pd

# %%
from process_file import CreateDataframes

# %%
c_df = CreateDataframes()

# %%
train_raw, test_raw, sub_raw = c_df.create_tabular_dataframes()

# %% [markdown]
# # Basic Exploration

# %%
# Helper Function

# !python -m wget https://raw.githubusercontent.com/train-your-model/helper_functions/master/basic_exploration.py

# %%
# Imports

from basic_exploration import Tabular

# %%
BE = Tabular(train_df= train_raw)
BE(prob_type=3)

# %% [markdown]
# **Observations:**

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **Observations:**
